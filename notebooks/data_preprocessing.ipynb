# %%
# Example notebook to visualize documents and embeddings

import matplotlib.pyplot as plt
from src.embeddings import load_pdf_text, generate_embeddings

docs, files = load_pdf_text("sample_docs")
embeddings = generate_embeddings(docs)

plt.imshow(embeddings[:10], aspect='auto', cmap='viridis')
plt.colorbar()
plt.title("Embeddings Heatmap for First 10 Documents")
plt.show()
